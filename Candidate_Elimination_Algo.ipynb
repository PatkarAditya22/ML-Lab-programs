# %% [markdown]
# <a href="https://colab.research.google.com/github/PatkarAditya22/ML-Lab-programs/blob/main/Candidate_Elimination_Algo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import csv

# %%
def g_0(n):
    return ("?",)*n

def s_0(n):
    return ('0',)*n

# %%
def more_general(h1, h2):
    more_general_parts = []
    for x, y in zip(h1, h2):
        mg = x == "?" or (x != "0" and (x == y or y == "0"))
        more_general_parts.append(mg)
    return all(more_general_parts)

l1 = [1, 2, 3]
l2 = [3, 4, 5]

list(zip(l1, l2))
# Out:
# [(1, 3), (2, 4), (3, 5)]

# %%
# min_generalizations
def fulfills(example, hypothesis):
    ### the implementation is the same as for hypotheses:
    return more_general(hypothesis, example)

def min_generalizations(h, x):
    h_new = list(h)
    for i in range(len(h)):
        if not fulfills(x[i:i+1], h[i:i+1]):
            h_new[i] = '?' if h[i] != '0' else x[i]
    return [tuple(h_new)]

# %%
min_generalizations(h=('0', '0'  , 'sunny'), 
                    x=('rainy', 'windy', 'cloudy'))
# Out:
# [('rainy', 'windy', '?')]

# %%
def min_specializations(h, domains, x):
    results = []
    for i in range(len(h)):
        if h[i] == "?":
            for val in domains[i]:
                if x[i] != val:
                    h_new = h[:i] + (val,) + h[i+1:]
                    results.append(h_new)
        elif h[i] != "0":
            h_new = h[:i] + ('0',) + h[i+1:]
            results.append(h_new)
    return results

# %%
min_specializations(h=('?', 'x',), 
                    domains=[['a', 'b', 'c'], ['x', 'y']], 
                    x=('b', 'x'))
# Out:
# [('a', 'x'), ('c', 'x'), ('?', '0')]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f2634022-545e-432c-a2ec-2f2b189120fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f2634022-545e-432c-a2ec-2f2b189120fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving titanic.csv to titanic (1).csv

# %%
import numpy as np
import pandas as pd
df=pd.read_csv(r"titanic.csv")

# %%
df
# Out:
#      Survived  Pclass  ... Parents/Children Aboard     Fare
# 0           0       3  ...                       0   7.2500
# 1           1       1  ...                       0  71.2833
# 2           1       3  ...                       0   7.9250
# 3           1       1  ...                       0  53.1000
# 4           0       3  ...                       0   8.0500
# ..        ...     ...  ...                     ...      ...
# 882         0       2  ...                       0  13.0000
# 883         1       1  ...                       0  30.0000
# 884         0       3  ...                       2  23.4500
# 885         1       1  ...                       0  30.0000
# 886         0       3  ...                       0   7.7500
#
# [887 rows x 8 columns]

# %%
m=len(df.axes[0])
n=len(df.axes[1])

# %%
ages = ["minor", "major"]
x=-1
for i in range(m):
    if df.iloc[i, 4] <= 18:
        x = 0
    else:
        x = 1
    df.iloc[i, 4] = ages[x]

# %%
df
# Out:
#      Survived  Pclass  ... Parents/Children Aboard     Fare
# 0           0       3  ...                       0   7.2500
# 1           1       1  ...                       0  71.2833
# 2           1       3  ...                       0   7.9250
# 3           1       1  ...                       0  53.1000
# 4           0       3  ...                       0   8.0500
# ..        ...     ...  ...                     ...      ...
# 882         0       2  ...                       0  13.0000
# 883         1       1  ...                       0  30.0000
# 884         0       3  ...                       2  23.4500
# 885         1       1  ...                       0  30.0000
# 886         0       3  ...                       0   7.7500
#
# [887 rows x 8 columns]

# %%
df.drop(['Name','Fare'],inplace=True,axis=1)

# %%
df
# Out:
#      Survived  Pclass  ... Siblings/Spouses Aboard Parents/Children Aboard
# 0           0       3  ...                       1                       0
# 1           1       1  ...                       1                       0
# 2           1       3  ...                       0                       0
# 3           1       1  ...                       1                       0
# 4           0       3  ...                       0                       0
# ..        ...     ...  ...                     ...                     ...
# 882         0       2  ...                       0                       0
# 883         1       1  ...                       0                       0
# 884         0       3  ...                       1                       2
# 885         1       1  ...                       0                       0
# 886         0       3  ...                       0                       0
#
# [887 rows x 6 columns]

# %%
cols=list(df.columns)
cols=['Pclass',
 'Sex',
 'Age',
 'Siblings/Spouses Aboard',
 'Parents/Children Aboard','Survived']
df=df.reindex(columns=cols)

# %%
df
# Out:
#      Pclass     Sex  ... Parents/Children Aboard  Survived
# 0         3    male  ...                       0         0
# 1         1  female  ...                       0         1
# 2         3  female  ...                       0         1
# 3         1  female  ...                       0         1
# 4         3    male  ...                       0         0
# ..      ...     ...  ...                     ...       ...
# 882       2    male  ...                       0         0
# 883       1  female  ...                       0         1
# 884       3  female  ...                       2         0
# 885       1    male  ...                       0         1
# 886       3    male  ...                       0         0
#
# [887 rows x 6 columns]

# %%
for i in range(m):
    if df.iloc[i, 5] == 0:
        df.iloc[i, 5] = 0
    else:
        df.iloc[i, 5] = 1

# %%
df
# Out:
#      Pclass     Sex  ... Parents/Children Aboard  Survived
# 0         3    male  ...                       0         0
# 1         1  female  ...                       0         1
# 2         3  female  ...                       0         1
# 3         1  female  ...                       0         1
# 4         3    male  ...                       0         0
# ..      ...     ...  ...                     ...       ...
# 882       2    male  ...                       0         0
# 883       1  female  ...                       0         1
# 884       3  female  ...                       2         0
# 885       1    male  ...                       0         1
# 886       3    male  ...                       0         0
#
# [887 rows x 6 columns]

# %%
examples = [tuple(x) for x in df[cols].to_numpy()]
#examples = examples[:10]

# %%
examples
# Out:
# [(3, 'male', 'major', 1, 0, 0),
#  (1, 'female', 'major', 1, 0, 1),
#  (3, 'female', 'major', 0, 0, 1),
#  (1, 'female', 'major', 1, 0, 1),
#  (3, 'male', 'major', 0, 0, 0),
#  (3, 'male', 'major', 0, 0, 0),
#  (1, 'male', 'major', 0, 0, 0),
#  (3, 'male', 'minor', 3, 1, 0),
#  (3, 'female', 'major', 0, 2, 1),
#  (2, 'female', 'minor', 1, 0, 1),
#  (3, 'female', 'minor', 1, 1, 1),
#  (1, 'female', 'major', 0, 0, 1),
#  (3, 'male', 'major', 0, 0, 0),
#  (3, 'male', 'major', 1, 5, 0),
#  (3, 'female', 'minor', 0, 0, 0),
#  (2, 'female', 'major', 0, 0, 1),
#  (3, 'male', 'minor', 4, 1, 0),
#  (2, 'male', 'major', 0, 0, 1),
#  (3, 'female', 'major', 1, 0, 0),
#  (3, 'female', 'major', 0, 0, 1),
#  (2, 'male', 'major', 0, 0, 0),
#  (2, 'male', 'major', 0, 0, 1),
#  (3, 'female', 'minor', 0, 0, 1),
#  (1, 'male', 'major', 0, 0, 1),
#  (3, 'female', 'minor', 3, 1, 0),
#  (3, 'female', 'major', 1, 5, 1),
#  (3, 'male', 'major', 0, 0, 0),
#  (1, 'male', 'major', 3, 2, 0),
# ...

# %%
def get_domains(examples):
    d = [set() for i in examples[0]]
    for x in examples:
        for i, xi in enumerate(x):
            d[i].add(xi)
    return [list(sorted(x)) for x in d]

get_domains(examples)
# Out:
# [[1, 2, 3],
#  ['female', 'male'],
#  ['major', 'minor'],
#  [0, 1, 2, 3, 4, 5, 8],
#  [0, 1, 2, 3, 4, 5, 6],
#  [0, 1]]

# %%
def candidate_elimination(examples):
    domains = get_domains(examples)[:-1]
    
    G = set([g_0(len(domains))])
    S = set([s_0(len(domains))])
    # print("S:-------------",S)
    i=0
    print("\n G[{0}]:".format(i),G)
    print("\n S[{0}]:".format(i),S)
    for xcx in examples:
        i=i+1
        x, cx = xcx[:-1], xcx[-1]  # Splitting data into attributes and decisions
        # if i==1:
        #   print("hi x is {} cx is {}".format(x,cx))
        if cx=='Y': # x is positive example
            G = {g for g in G if fulfills(x, g)}
            S = generalize_S(x, G, S)
        else: # x is negative example
            S = {s for s in S if not fulfills(x, s)}
            G = specialize_G(x, domains, G, S)
        print("\n G[{0}]:".format(i),G)
        print("\n S[{0}]:".format(i),S)
    return G

# %%
def candidate_elimination2(examples):
    domains = get_domains(examples)[:-1]
    
    G = set([g_0(len(domains))])
    S = set([s_0(len(domains))])
    # print("S:-------------",S)
    i=0
    print("\n G[{0}]:".format(i),G)
    print("\n S[{0}]:".format(i),S)
    for xcx in examples:
        i=i+1
        x, cx = xcx[:-1], xcx[-1]  # Splitting data into attributes and decisions
        # if i==1:
        #   print("hi x is {} cx is {}".format(x,cx))
        if cx=='Y': # x is positive example
            S = {s for s in S if not fulfills(x, s)}
            G = specialize_G(x, domains, G, S)
        else: # x is negative example
            G = {g for g in G if fulfills(x, g)}
            S = generalize_S(x, G, S)            
        print("\n G[{0}]:".format(i),G)
        print("\n S[{0}]:".format(i),S)
    return S

# %%
def generalize_S(x, G, S):
    S_prev = list(S)
    for s in S_prev:
        if s not in S:
            continue
        if not fulfills(x, s):
            S.remove(s)
            Splus = min_generalizations(s, x)
            ## keep only generalizations that have a counterpart in G
            S.update([h for h in Splus if any([more_general(g,h) 
                                               for g in G])])
            ## remove hypotheses less specific than any other in S
            S.difference_update([h for h in S if 
                                 any([more_general(h, h1) 
                                      for h1 in S if h != h1])])
    return S

# %%
def specialize_G(x, domains, G, S):
    G_prev = list(G)
    for g in G_prev:
        if g not in G:
            continue
        if fulfills(x, g):
            G.remove(g)
            Gminus = min_specializations(g, domains, x)
            ## keep only specializations that have a conuterpart in S
            G.update([h for h in Gminus if any([more_general(h, s)
                                                for s in S])])
            ## remove hypotheses less general than any other in G
            G.difference_update([h for h in G if 
                                 any([more_general(g1, h) 
                                      for g1 in G if h != g1])])
    return G

# %%
G = candidate_elimination(examples)
S = candidate_elimination2(examples)
G = list(G)
S = list(S)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# ...

# %%
print(G[-1],S[-1])
# Out:
# (2, 'male', '?', 3, '?') ('?', '?', '?', '?', '?')
